# %%
import torch
import d2l
print("PyTorch 版本:", torch.__version__)
print("CUDA 是否可用:", torch.cuda.is_available())  # 必须输出False
print("d2l 导入成功！")
# Out:
# PyTorch 版本: 2.1.0+cpu
# CUDA 是否可用: False
# d2l 导入成功！
